# %% [markdown]
# # Exercício:

# %% [markdown]
# ## 01 – Cite três vantagens do uso das funções e duas características que toda função deva ter?

# %% [markdown]
# R.: 1- Elas simplificam processos, pois depois de definidas podem ser chamadas em diversas vezes do código
# <br>2- Servem para resolver o problema com a repetição de parametros, deixando o código organizado
# <br>3- Além de receber dados ela também retorna dados
# <br>4- ela deve começar com 'def' e ter identação dos parametros para poder ser compreendida

# %% [markdown]
# ## Responda a pergunta do exercício 2 da aula 10, usando funções:<br>
# Instancie um objeto da classe NumPy array, contendo 5 valores quantitativos randômicos normalmente distribuídos, com média 10 e desvio padrão 3.<br><br>
# Quantos e quais são os valores superiores a 10?

# %% [markdown]
# ## 02 – Descreva o racional da sua resposta:

# %% [markdown]
# R.: 1- Instanciar array de acordo com o solicitado
# <br>2- criar função para reconhecer os que são maiores de 10 e quantos são
# <br>3- Puxar a função a onde vc quer que ela conte quais e quantos são os maiores de 10

# %% [markdown]
# ## 03 – Desenhe o fluxograma da resposta:

# %% [markdown]
# <img src="../img/Fluxograma_ex10.png" width="400"/>

# %% [markdown]
# ## 04 – Escreva o programa em Python:

# %%
import numpy as np

# %%
algo = np.random.normal(10, 3, 5)
algo
# Out:
# array([ 7.60691904, 10.17069037,  6.9776392 ,  6.95387422,  4.57897328])

# %%
def define_10(algo):
    quais_10 = print("Esses são os maiores que 10:", algo[algo > 10])
    maiores_10 = print("Quantidade de maiores que 10:", (algo > 10).sum())
    return quais_10, maiores_10

# %%
resultado = define_10(algo)
resultado
# Out:
# Esses são os maiores que 10: [10.17069037]
# Quantidade de maiores que 10: 1
# (None, None)

# %% [markdown]
# ## 05 – Seria possível, com o racional proposto, saber quantos e quais valores são superiores a 20? Porque?

# %% [markdown]
# ##R: É possível, mas a mensagem ficará vazia o que é feio, então para conseguir incluir um if else eu modifiquei a função

# %%
def define_20(algo):
    quais_20 = print("Esses são os maiores que 20:", algo[algo > 20])
    maiores_20 = print("Quantidade de maiores que 20:", (algo > 20).sum())
    
    return quais_20, maiores_20

resultado_20= define_20(algo)
# Out:
# Esses são os maiores que 20: []
# Quantidade de maiores que 20: 0

# %%
def define_20_2(algo):
    quais_20_2 = algo[algo > 20]
    maiores_20_2 = (algo > 20).sum()

    return quais_20_2, maiores_20_2

lista_maiores, contagem = define_20_2(algo)

if contagem == 0:
    print("Não há números maiores que 20")
else:
    print(f"Esses são os maiores que 20: {lista_maiores}")
    print(f"Quantidade de maiores que 20: {contagem}")
# Out:
# Não há números maiores que 20

# %% [markdown]
# ## Desenvolva um programa de computador que retorne a média de um conjunto de valores.

# %% [markdown]
# ## 06 – Descreva o racional da sua resposta:

# %% [markdown]
# R.: Definir uma variavel contendo os valores a serem feitos a média
# Criar a função onde vai somar os valores que contenham dentro da variavel e divididas pelo quantidade de valores presentes na variavel
# retornar o valor utilizando a função

# %% [markdown]
# ## 07 – Desenhe o fluxograma da resposta:

# %% [markdown]
# <img src="../img/Fluxograma_ex10_1.png" width="400"/>

# %% [markdown]
# ## 08 – Escreva o programa em Python:

# %%
notas = (20, 13, 8, 15, 20)

def calcular_media(notas):
    media = sum(notas) / len(notas)
    return media

resultado_notas = calcular_media(notas)
print('A média de', notas, 'é:', resultado_notas)
# Out:
# A média de (20, 13, 8, 15, 20) é: 15.2

# %% [markdown]
# ## 09 – Desenvolva um programa de computador que retorne a divisão de dois objetos simples. Seu programa deve ser capaz de reconhecer a classe destes objetos e o valor, antes de retornar ao usuário.

# %%
def divisao(num1, num2):
    print(f'Objeto 1- Classe:',(type(num1)), '- Valor:', num1)
    print(f'Objeto 2- Classe:',(type(num2)), '- Valor:', num2)

    if num2 == 0:
        return "Divisão por 0 não permitida"
    else:
        return num1 / num2

# %%
resulado_obj = divisao(28, 17)
print(resulado_obj)
# Out:
# Objeto 1- Classe: <class 'int'> - Valor: 28
# Objeto 2- Classe: <class 'int'> - Valor: 17
# 1.6470588235294117

# %% [markdown]
# ## 10 – Desenvolva um programa de computador que retorne a divisão de dois objetos compostos. Seu programa deve ser capaz de reconhecer a classe destes objetos e o valor, antes de retornar ao usuário.

# %%
def divisao_comp(num_1, num_2):
    print(f'Objeto 1- Classe:',(type(num_1)), '- Valor:', num_1)
    print(f'Objeto 2- Classe:',(type(num_2)), '- Valor:', num_2)

    if (len(num_1) != len(num_2)):
        print('O tamanho dos objetos não é o mesmo')
    else:
        return num_1 / num_2

# %%
resultado_div = divisao_comp([30, 20, 15],[3, 2, 3])

## Eu teria que criar um novo dicionário para cada divisão de index, é pra fazer isso?
# Out:
# Objeto 1- Classe: <class 'list'> - Valor: [30, 20, 15]
# Objeto 2- Classe: <class 'list'> - Valor: [3, 2, 3]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 resultado_div = divisao_comp([30, 20, 15],[3, 2, 3])
#
# Cell In[18], line 8, in divisao_comp(num_1, num_2)
#       6     print('O tamanho dos objetos não é o mesmo')
#       7 else:
# ----> 8     return num_1 / num_2
#
# TypeError: unsupported operand type(s) for /: 'list' and 'list'
