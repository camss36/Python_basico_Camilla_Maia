# %%
simbolo = [
   "IFNG",
   "IL10",
   "TnF",
   "CSF2",
]

full_name = [
    "Interferon gamma",
    "Interleukin 10",
    "Tumor necrosis factor",
    "Colony stimulating factor 2",
]

source = [
    "HGNC:HGNC:5438",
    "RGD:2886",
    "MGI:MGI:104798",
    "HGNC:HGNC:2434",
]
gene_type = [
    'protein coding',
    'protein coding',
    'protein coding',
    'protein coding'
]
organism = [
    'Homo sapiens',
    'Rattus norvegicus',
    'Mus musculus',
    'Homo sapiens'
]
chromosome = [
    12,
    13,
    17,
    5
]

# %%
gene_matriz_lista = [
    simbolo,
    full_name,
    source,
    gene_type,
    organism,
    chromosome
]
gene_matriz_lista
# Out:
# [['IFNG', 'IL10', 'TnF', 'CSF2'],
#  ['Interferon gamma',
#   'Interleukin 10',
#   'Tumor necrosis factor',
#   'Colony stimulating factor 2'],
#  ['HGNC:HGNC:5438', 'RGD:2886', 'MGI:MGI:104798', 'HGNC:HGNC:2434'],
#  ['protein coding', 'protein coding', 'protein coding', 'protein coding'],
#  ['Homo sapiens', 'Rattus norvegicus', 'Mus musculus', 'Homo sapiens'],
#  [12, 13, 17, 5]]

# %% [markdown]
# fazer um dicionario, as chaves serão os nomes das listas em str e os valores as listas

# %%
dicionario_gene = {
    "simbolo": simbolo,
    "full_name": full_name,
    "source": source,
    "gene_type": gene_type,
    "organism": organism,
    "chromosome": chromosome
}
dicionario_gene
# Out:
# {'simbolo': ['IFNG', 'IL10', 'TnF', 'CSF2'],
#  'full_name': ['Interferon gamma',
#   'Interleukin 10',
#   'Tumor necrosis factor',
#   'Colony stimulating factor 2'],
#  'source': ['HGNC:HGNC:5438', 'RGD:2886', 'MGI:MGI:104798', 'HGNC:HGNC:2434'],
#  'gene_type': ['protein coding',
#   'protein coding',
#   'protein coding',
#   'protein coding'],
#  'organism': ['Homo sapiens',
#   'Rattus norvegicus',
#   'Mus musculus',
#   'Homo sapiens'],
#  'chromosome': [12, 13, 17, 5]}

# %%
gene_matriz_lista[0]
# Out:
# ['IFNG', 'IL10', 'TnF', 'CSF2']

# %%
dicionario_gene["simbolo"]
# Out:
# ['IFNG', 'IL10', 'TnF', 'CSF2']

# %%
#simbolo.append('actina')
simbolo
# Out:
# ['IFNG', 'IL10', 'TnF', 'CSF2', 'actina', 'actina']

# %%
import numpy as np
import pandas as pd

# %%
gene_array = np.array(gene_matriz_lista)
gene_array
# Out:
# array([['IFNG', 'IL10', 'TnF', 'CSF2'],
#        ['Interferon gamma', 'Interleukin 10', 'Tumor necrosis factor',
#         'Colony stimulating factor 2'],
#        ['HGNC:HGNC:5438', 'RGD:2886', 'MGI:MGI:104798', 'HGNC:HGNC:2434'],
#        ['protein coding', 'protein coding', 'protein coding',
#         'protein coding'],
#        ['Homo sapiens', 'Rattus norvegicus', 'Mus musculus',
#         'Homo sapiens'],
#        ['12', '13', '17', '5']], dtype='<U27')

# %%
gene_array.shape
# Out:
# (6, 4)

# %%
index = [1, 2, 3]
gene_array[index]
# Out:
# array([['Interferon gamma', 'Interleukin 10', 'Tumor necrosis factor',
#         'Colony stimulating factor 2'],
#        ['HGNC:HGNC:5438', 'RGD:2886', 'MGI:MGI:104798', 'HGNC:HGNC:2434'],
#        ['protein coding', 'protein coding', 'protein coding',
#         'protein coding']], dtype='<U27')

# %%
gene_array[:,0]
# Out:
# array(['IFNG', 'Interferon gamma', 'HGNC:HGNC:5438', 'protein coding',
#        'Homo sapiens', '12'], dtype='<U27')

# %%
gene_array[:,[1,0]]
# Out:
# array([['IL10', 'IFNG'],
#        ['Interleukin 10', 'Interferon gamma'],
#        ['RGD:2886', 'HGNC:HGNC:5438'],
#        ['protein coding', 'protein coding'],
#        ['Rattus norvegicus', 'Homo sapiens'],
#        ['13', '12']], dtype='<U27')

# %%
gene_array[:,1]
# Out:
# array(['IL10', 'Interleukin 10', 'RGD:2886', 'protein coding',
#        'Rattus norvegicus', '13'], dtype='<U27')
