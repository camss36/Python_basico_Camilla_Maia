# %%
tupla = ("Camilla", "12 de Julho", "Curitiba")
tupla
# Out:
# ('Camilla', '12 de Julho', 'Curitiba')

# %%
type(tupla)
# Out:
# tuple

# %%
lista = ["Marrom", "verde", "laranja"]
lista
# Out:
# ['Marrom', 'verde', 'laranja']

# %%
type(lista)
# Out:
# list

# %%
dicionario = {"nome": "Camilla", 
              "data de nascimento": "12 de Julho", 
              "cidade": "Curitiba"}
dicionario
# Out:
# {'nome': 'Camilla', 'data de nascimento': '12 de Julho', 'cidade': 'Curitiba'}

# %%
type(dicionario)
# Out:
# dict

# %%
print(tupla)
tupla[2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 print(tupla)
#       2 tupla[2]
#
# NameError: name 'tupla' is not defined

# %%
dicionario['cpf']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 dicionario['cpf']
#
# KeyError: 'cpf'

# %%
dicionario['cpf'] = "123.456.789-00"
dicionario
# Out:
# {'nome': 'Camilla',
#  'data de nascimento': '12 de Julho',
#  'cidade': 'Curitiba',
#  'cpf': '123.456.789-00'}

# %%
lista[-1]
# Out:
# 'laranja'

# %%
help(list)
# Out:
# Help on class list in module builtins:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
# ...

# %%
lista.append("azul")
lista
# Out:
# ['Marrom', 'verde', 'laranja', 'azul']

# %%
lista = ["amarelo", "preto", "branco"]
print(f"{lista}")
lista.append("roxo")
print(f"Lista atualizada: {lista}")
# Out:
# ['amarelo', 'preto', 'branco']
# Lista atualizada: ['amarelo', 'preto', 'branco', 'roxo']

# %%
dicionario['cep'] = "12345-678"
dicionario
# Out:
# {'nome': 'Camilla',
#  'data de nascimento': '12 de Julho',
#  'cidade': 'Curitiba',
#  'cpf': '123.456.789-00',
#  'cep': '12345-678'}

# %%
lista.pop() # Remove o último item da lista
lista
# Out:
# ['amarelo', 'preto']

# %%
lista = ["amarelo", "preto", "branco"]
num = lista.pop()
print(f"Item removido: {num} - {lista}")
# Out:
# Item removido: branco - ['amarelo', 'preto']

# %%
lista = [1, 2, 3, 4, 5]
novo_objeto = lista[3]
novo_objeto
# Out:
# 4

# %%
a, b, c, *d, e= lista
print(a, b, c, d, e)
# Out:
# 1 2 3 [4] 5
