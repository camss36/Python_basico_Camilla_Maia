# %% [markdown]
# # Exercício 1
# ## R: A resposta do terminal será "Substitua"

# %% [markdown]
# # Exercício 2
# ## R: A condicional lampada ligada deve ser true e a condicional bocal queimado deve ser false

# %% [markdown]
# # Exercício 3
# ## R: linha 6

# %% [markdown]
# # Exercício 4
# <img src="../img/fluxograma_cafe_refeito.jpeg" width="400"/>
